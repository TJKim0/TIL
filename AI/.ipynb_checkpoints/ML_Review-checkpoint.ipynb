# %% [markdown]
# # 머신러닝과 딥러닝의 이해
# ## 지도학습 (Supervised learning)
# * 분류모델 (Classification models)
# * 회귀모델 (Regression models)
#
# ## 비지도 학습 (Unsupervised learning)
# * 클러스터링
# * Density estimation
# * Dimension reduction
# * Anomaly detection

# %% [markdown]
# ### 데이터 형태 종류
# * vector, matrix, tensor
#     * 정형 데이터 : (sequence length x feature) 형태의 matrix. ex) 시계열 데이터
#     * 이미지 데이터 : (3 x W x H ) 형태의 tensor.
#     * 언어 데이터 : (sequence length) 현태의 vector.

# %% [markdown]
# ### 모델
# * 입력된 데이터를 vector, matrix, tensor 연산을 통해 새로운 결과를 도출.

# %% [markdown]
# ### 손실 함수 (Loss function)
# * 모델이 입력된 데이터를 어떻게 모델링 할 것인지 결정.

# %% [markdown]
# ### 최적화 방법
# * 모델이 손실함수를 어떤 방식으로 최적화 할 것인지 결정.
# ![image.png](attachment:image.png)

# %% [markdown]
# ## ML, DL 적용과정 **** work flow 매우 중요
# 1. raw data
# 2. data preparation
# 3. model selection
# 4. train a model
# 5. model evaluation
# 6. production
# 7. prediction
# 8. back to 'raw data'

# %% [markdown]
# ### overfit, underfit  해결법
# * validation
# * data 량을 늘린다
# * regularization - drop out
# * cross validation

# %% [markdown]
#  1. 모델 평가 지표
#  * loss
#  * precision, recall, fi-score, acc, auc, mse, mae, mape, smape
#
#
#  2. train/validation, cross-validation, 새로운 데이터에 평가

# %% [markdown]
# ## ML 기본 개념들
# * Models
# * Loss function
#     * regression
#         * l1 loss
#         * l2 loss
#         * hinge loss (SVM 에서 쓰임)
#
#     * classification
#         * cross entropy loss
#         * kl divergence loss
#     * etc
#         * cosine similarity loss
#         * dice loss
#
#     * ...
#
# * Training/ Validation / Test sets
#     * k-fold cross validation
#
# * Regularization (Loss supporter)
#     * L1 regularization
#     * L2 regularization
#
# * Gradient descent optimization
#     * Batch gradient descent
#     * Stochastic gradient descent
#         * Momentum
#             * Adagrad
#             * Adam
#             * Adadelta
#             * RMSprop
#             * ...
#
# * Model selection and hyper parameter optimization
#     * grid search
#     * Random search << better performance
#
# * Bias/Variance tradeoff
#     * Overfitting
#     * Underfitting
#
# * Evaluation metrics
#     * Classification
#         * Accuracy
#         * Recall
#         * precision
#         * f1- score
#         * confusion matrix
#     * Regression
#         * Mean absolute error
#         * Mean squared error
#         * Mean absolute percentage error
#         * Scaled mean absolute percentage error
#
# * Ensemble model
#     * bagging
#     * boosting
#
# *
